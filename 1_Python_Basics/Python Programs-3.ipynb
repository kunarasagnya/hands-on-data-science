# %%
s=input()
lt=list(s)
i=0
while i<len(lt)-1:
  if lt[i]==lt[i+1]:
    lt.pop(i)
    lt.pop(i)
    if i>0:
      i=i-1
  else:
    i=i+1
print("".join(lt))
# Out:
# abbcad
# acad

# %%
st=input()
lt=list(st)
i=0
while i<len(lt)-1:
    if lt[i]==lt[i+1]:
        lt.pop(i)
        lt.pop(i)
        if i>0:
            i-=1
    else:
        i=i+1
print("".join(lt))
# Out:
# aeebb
# a

# %% [markdown]
# Problem Statement
# You are given a string s of even length. Split this string into two halves of equal lengths, and let a be the first half and b be the second half.
#
# Two strings are alike if they have the same number of vowels ('a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U'). Notice that s contains uppercase and lowercase letters.
#
# Return true if a and b are alike. Otherwise, return false.
#
#
#
# Input Format
# A string will be passed.
#
# Output Format
# A boolean value will be returned.
#
# Constraints
# 2 <= s.length<= 1000
# length is even.
# s consists of uppercase and lowercase letters.
#
# Sample Testcase 0
# Testcase Input
# textbook
# Testcase Output
# false

# %%
def halvesAreAlike(S):
  if len(S)<2:
    return False
  else:
    st=S.lower()
    mid=len(st)//2
    a=st[:mid]
    b=st[mid:]
    vowels="aeiou"
    lt_a=[i for i in a if i in vowels]
    lt_b=[i for i in b if i in vowels]
    if len(lt_a)!=len(lt_b):
        return False
    return set(lt_a)==set(lt_b)

if __name__ == "__main__":
    str = input()
    ans = halvesAreAlike(str)
    print("true" if ans else "false")
# Out:
# r
# false
